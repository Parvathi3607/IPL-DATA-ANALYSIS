# %% [markdown]
# # movie rating analysis(advanced visualization)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
movies = pd.read_csv(r"C:\Users\Parva\OneDrive\Desktop\naresh it\25th\25th\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv")
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
# movies.columns
movies['Audience Ratings %'].mode()
# Out:
# 0    50
# 1    57
# 2    72
# Name: Audience Ratings %, dtype: int64

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.isnull().sum()
# Out:
# Film              0
# Genre             0
# CriticRating      0
# AudienceRating    0
# BudgetMillions    0
# Year              0
# dtype: int64

# %%
# movies['Genre'].value_counts().plot(kind='kde')
sns.histplot(movies['Genre'].sort_values(ascending=False))
# Out:
# <Axes: xlabel='Genre', ylabel='Count'>

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Genre.nunique()
# Out:
# 7

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
# working with joint plots
j = sns.jointplot(data=movies, x= 'CriticRating',y='AudienceRating')

# %%
j = sns.jointplot(data= movies, x='CriticRating',y = 'AudienceRating',kind='reg')
## kind = { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
j = sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind = 'hex')

# %%
j = sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind = 'scatter')

# %%
j = sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind = 'resid')

# %%
j = sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind = 'kde')

# %%
j = sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind = 'hist')

# %%
# histogram
## chart
movies['AudienceRating'].min()
# Out:
# 0

# %%
h= sns.distplot(movies.AudienceRating)

# %%
sns.set_style('whitegrid')
h= sns.distplot(movies.AudienceRating)
## {darkgrid, whitegrid, dark, white, ticks}

# %%
sns.set_style('darkgrid')
h= sns.distplot(movies.AudienceRating, bins=10)

# %%
c =plt.hist(movies.CriticRating, bins=20)       # uniform distribution

# %%
sns.set_style('white')
# a = plt.hist(movies.AudienceRating,bins=15)AudienceRating
sns.distplot(movies.AudienceRating)
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Density'>

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins=20)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,movies[movies.Genre == 'Drama'].BudgetMillions,movies[movies.Genre == 'Comedy'].BudgetMillions,movies[movies.Genre == 'Thriller'].BudgetMillions],bins=20,stacked=True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things
for i in movies.Genre.cat.categories:
    print(i)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
vis1 = sns.lmplot(data = movies, x='CriticRating',y='AudienceRating',fit_reg = False)

# %%
vis1 = sns.lmplot(data = movies, x='CriticRating',y='AudienceRating',fit_reg = False , hue='Genre')

# %%
vis1 = sns.lmplot(data = movies, x='CriticRating',y='AudienceRating',fit_reg = False,hue='Genre',aspect=1,height=10)
sns.set_style('darkgrid')

# %%
# Kernal Density Estimate plot ( KDE PLOT) 
# how can i visulize audience rating & critics rating . using scatterplot

# %%
sns.set_style('white')
k = sns.kdeplot(data = movies,x = movies.CriticRating,y = movies.AudienceRating)

# %%
k2 = sns.kdeplot(data= movies ,x= 'CriticRating',y='AudienceRating',shade= True , shade_lowest = False,cmap='Blues')

# %%
k2 = sns.kdeplot(data = movies,x ='CriticRating',y='AudienceRating',shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
k3= sns.kdeplot(data = movies , x = 'BudgetMillions',y='AudienceRating',shape=False,shade_lowest=False,cmap='Blues')

# %%
sns.set_style('dark')
k4 = sns.kdeplot(data= movies,x='BudgetMillions',y='AudienceRating')

# %%
k2 = sns.kdeplot(data= movies,x= 'BudgetMillions',y='CriticRating')

# %%
# subplot
s = plt.subplots(2,1, figsize =(10,5))

# %%
s = plt.subplots(3,3, figsize =(10,5))

# %%
f , axes= plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(data = movies,x='BudgetMillions',y='AudienceRating',ax = axes[0])
k2 = sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',ax = axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
# boxplot
b = sns.boxplot(data=movies,x='Genre',y='CriticRating')

# %%
b = sns.boxplot(data=movies,x='Genre',y='AudienceRating')

# %%
b = sns.violinplot(data=movies,x='Genre',y='AudienceRating')

# %%
sns.set_style("white")
b2 = sns.boxplot(data= movies[movies.Genre == 'Drama'], x= 'Year',y='CriticRating')

# %%
v2 = sns.violinplot(movies[movies.Genre == 'Drama'],x = 'Year',y = 'CriticRating')

# %%
# creating a Facet grid

# %%
F = sns.FacetGrid(data= movies,row='Genre',col='Year')

# %%
plt.scatter(data= movies,x='CriticRating',y='AudienceRating')

# %%
sns.set_style('dark')
g = sns.FacetGrid(data= movies,row='Genre',col='Year',hue='Genre')
g = g.map(plt.scatter,'CriticRating','AudienceRating')

# %%
sns.set_style('dark')
g = sns.FacetGrid(data= movies,row="Genre",col='Year',hue='Genre')
g = g.map(plt.hist,'BudgetMillions')

# %%
sns.set_style('dark')
g = sns.FacetGrid(data= movies,row="Genre",col='Year',hue='Genre')
g = g.map(plt.hist,'AudienceRating')

# %%
g = sns.FacetGrid(data= movies,row="Genre",col='Year',hue='Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='white')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating') #scatterplots are mapped in facetgrid

# %%
sns.set_style('dark')
f , axes = plt.subplots(2,2,figsize=(10,10))
k1 = sns.kdeplot(data= movies,x='BudgetMillions',y='AudienceRating',ax=axes[0,0])
k2= sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',ax=axes[0,1])
k1.set(xlim=(-50,230))
k2.set(ylim=(-20,160))

v = sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating',ax=axes[1,0])
k4 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(data=movies,x='CriticRating', y='AudienceRating',cmap='Reds',ax = axes[1,1])

plt.show()

# %%
sns.set_style('dark')
f , axes = plt.subplots(2,2,figsize=(10,10))
k1 = sns.kdeplot(data= movies,x='BudgetMillions',y='AudienceRating',ax=axes[0,0])
k2= sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',ax=axes[0,1])
k1.set(xlim=(-50,230))
k2.set(ylim=(-20,160))

v = sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='AudienceRating',ax=axes[1,0])
k4 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(data=movies,x='CriticRating', y='AudienceRating',cmap='Reds',ax = axes[1,1])

plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

# %%
k1 = sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating',shade = True, shade_lowest=True,cmap = 'inferno', 
                  ax = axes[0,0])
k1b = sns.kdeplot(data=movies,x='BudgetMillions', y='AudienceRating',cmap = 'cool',ax = axes[0,0])
