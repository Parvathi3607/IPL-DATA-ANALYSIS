# %% [markdown]
# # HEART DISESASE

# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as st
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\Parva\OneDrive\Desktop\naresh it\archive (2)\heart.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
print(df.shape)         # print the shape means how many rows and columns
# Out:
# (1025, 14)

# %%
df.head()               # preview dataset
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()          # summary of dataset
# df.info command gives us the number of filled values along with data types of columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.dtypes  # to check the datatype of a particular column
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# #### statisticial properties of dataset

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.columns      # view colum names
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# ##Analysis of target feature variable
# 1 . our feature variable of intreset is target
# 2. it refers to the presence of heart disease in the patient
# 3. it is integer valued as it contains two integers 0 and 1 -(0 -  stands for absence of heart disease and 1 stands for presence in heart disease).
# 4. so, in the section, i will analyse the target variable.

# %%
df['target'].nunique()
# Out:
# 2

# %%
df['target'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['target'].value_counts()   # frequency distribution of taarget variable
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %% [markdown]
# ## comment:
# 1 stands for presence of heart disease. so, there are 526 patients suffering from heart disease.
# similarly,0 stands for absence of heart disease . so, there are 499 patients who are not have any heart disease.

# %% [markdown]
# ##Visualize frequency distribution of target variables

# %%
f, ax = plt.subplots(figsize=(10,6))
ax = sns.countplot(data = df , x ='target')
plt.show()

# %% [markdown]
# INTERPRETATION:
# ### the above plot shows the finding that:
# *there are 526 patients suffering from heart disease,and
# *there are 499 patients who donot have any heart disease.

# %% [markdown]
# ## frequency distribution of target variables wrt sex

# %%
df['sex'].value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1         226
#      0          86
# 1    0         413
#      1         300
# Name: target, dtype: int64

# %% [markdown]
# # comment:
# sex variable contains two integer valkuez 0 and 1 (1= male, 0 = feamle).
# target variable also contains two integer values 1 and 0 (1= presence of heart disease ; 0 = absence of heart disease)
# so, out of 312 females - 226 have heart disease and 86 donot have heart disease.
# similarly,out of 713 males - 300 have heart disease and 413 donot have heart disease

# %% [markdown]
# ## we can visualize the value counts of the sex variable wrt target as follows -

# %%
f, ax = plt.subplots(figsize=(10,5))
ax = sns.countplot(data=df , x= 'sex',hue = 'target')
plt.show()

# %%
ax = sns.catplot(data = df , x='target',col='sex',kind='count',height=5,aspect=1)

# %% [markdown]
# ## comment:
# * the above plot segregate the values of target variable and plot on two different labelled as (sex=0,sex=1)

# %%
f, ax = plt.subplots(figsize = (10,5))
ax = sns.countplot(data=df,y='target',hue='sex')
plt.show()

# %% [markdown]
# # we can use different colour palette as follows:

# %%
f, ax = plt.subplots(figsize=(10,5))
ax = sns.countplot(data=df , x='target',palette="Set3")
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,5))
ax = sns.countplot(data=df,x='target',facecolor=(1,1,0,0),linewidth=10,edgecolor=sns.color_palette("colorblind",3))
plt.show()   ## 'deep', 'pastel', 'dark', 'bright', 'muted', 'colorblind', etc.
             ## facecolor =(0,1)

# %%
f,ax = plt.subplots(figsize=(10,5))
ax = sns.countplot(data=df , x='target',hue='fbs')
plt.show()

# %%
f,ax = plt.subplots(figsize=(10,5))
ax = sns.countplot(data=df , x='target',hue='exang')
plt.show()

# %% [markdown]
# # findings of univariate analysis

# %% [markdown]
# * our feature variable of intrest is target
# * it refers to the presence of heartdisease in the patient.
# * it is integer valued as it contains two integrea 0 and 1 -(0 stands for absence of heart disease and 1 - stands for presence of heart disease)
# * 0 stands for absence of heart disease.so there are 499 patients who donot have any heart disease.
# * 1 stands for presence of heart disease.so,there are 526 patients suffering from heart disease
# * there are 499 patients who donot have any heart disease.
# * there are 526 patients suffering from heart disease
# * out of 312 females - 226 have heart disease and 86 donot have heart disease. *similarly,out of 713 males - 300 have heart disease and 413 donot have heart disease

# %% [markdown]
# # bivariate analysis

# %% [markdown]
# * our data set is very small.so,i will compute the standard correlation coefficient(also pearson's r) between every pair of attributes. i will compute it using the df.corr()

# %%
correlation = df.corr()                       # target variable is 'target'.so,we should check how each attribute correlates with the target variable
correlation['target'].sort_values(ascending = False)
# Out:
# target      1.000000
# cp          0.434854
# thalach     0.422895
# slope       0.345512
# restecg     0.134468
# fbs        -0.041164
# chol       -0.099966
# trestbps   -0.138772
# age        -0.229324
# sex        -0.279501
# thal       -0.337838
# ca         -0.382085
# exang      -0.438029
# oldpeak    -0.438441
# Name: target, dtype: float64

# %% [markdown]
# # interpretation of correlation coefficient
# * the correlation coefficient ranges from -1 to +1
# * when it is close to +1, this  significances that there is a strong positive correlation.
# * when it is close to -1, this  significances that there is a strong negative correlation.
# * when it is close to it means that there is no correlation.
# * here we can see that the 'cp' and 'thalach' variables are mildly positively correlated with target variable. so, i will analyse the interaction between these features and target variable.

# %%
df['cp'].nunique()   # there are 4  unique values in the cp variable.hence, it is a categorical variable.
# Out:
# 4

# %%
df['cp'].value_counts()    # frequency # how can you know cp is category why becoz it shows 0,1,2,3
# Out:
# 0    497
# 2    284
# 1    167
# 3     77
# Name: cp, dtype: int64

# %% [markdown]
# # comment:
# * it can be seen that cp is a categorical variable and it conntains 4 types of values - 0,1,2,3

# %% [markdown]
# # visualize the frequency distribution of the cp variable

# %%
f, ax = plt.subplots(figsize=(10,5))
ax = sns.countplot(data=df,x='cp')
plt.show()

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         375
#     1         122
# 1   1         134
#     0          33
# 2   1         219
#     0          65
# 3   1          51
#     0          26
# Name: target, dtype: int64

# %% [markdown]
# # comment:
# * cp variable contains four integer values 0,1,2,and 3.
# * target variable contains two integer values 1 and 0 (1 - presence of heart disease and 0 - absence of heart disease)
# * so, the above analysis gives target variable values categorized into presence and absence of heart disease and groupby cp variable values.

# %%
f, ax = plt.subplots(figsize=(10,5))
ax = sns.countplot(data=df,x='cp',hue='target')
plt.show()

# %%
ax = sns.catplot(data = df ,x='target',col='cp',kind='count',height=5,aspect=1)

# %% [markdown]
# ## Analysis of target and thalach variable

# %% [markdown]
# ### Explore thalach variable
# * thalach stands for maximum heart rate achieved.
# * i will check number of unique values in thalach variables as follows:

# %%
df['thalach'].nunique() # no.of unique values in thalach variable is 91. hence, it is numerical value
# Out:
# 91

# %%
sns.set_style('darkgrid')
f,ax = plt.subplots(figsize=(10,6))
x=df['thalach']
ax = sns.distplot(x,bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
ax = sns.distplot(x,bins=10,vertical=True)
plt.show()

# %% [markdown]
# # seaborn kernal density estimation(kde)plot
# * the kernal density estimate(kde) plot is a usefultool for plotting the shape of a distribution
# * the kde plot plots the density of observations on one axis with height along the other axis.

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x, shade=True, color='g')
plt.show()

# %% [markdown]
# # Histogram

# %%
f , ax = plt.subplots(figsize=(10,5))
x = df['thalach']
ax = sns.distplot(x,kde=False,rug=True,bins=10)
plt.show()

# %%
f , ax = plt.subplots(figsize=(10,5))
ax = sns.stripplot(x= 'target',y='thalach',data=df)
plt.show()

# %% [markdown]
# ## Interpretation
# * we can see that those people suffering from heart disease(target =1) have relatively hisgher rate(thalach) as compared to people who are not suffering form heart disease(target=0)

# %%
f , ax = plt.subplots(figsize=(10,5))
ax = sns.stripplot(data =df, x = 'target',y='thalach',jitter=0.01)
plt.show()

# %%
f , ax = plt.subplots(figsize=(10,5))
ax = sns.boxplot(data =df, x = 'target',y='thalach')
plt.show()

# %% [markdown]
# ## Interpretation
# * the above boxplot confirms our finding that people suffering from heart disease(target =1) have relatively higher heart rate(thalach) as compared to people who are not suffering from heart disease(target=0)

# %% [markdown]
# ## 9. Multivariate Analysis
# * The objective of the multivariate analysis is to discover patterns and relationship in the dataset

# %% [markdown]
# # Heat map

# %%
plt.figure(figsize=(15,11))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a = sns.heatmap(correlation,square=True,annot=True,fmt='.2f',linecolor='white')
a.set_xticklabels(a.get_xticklabels(),rotation=90)
a.set_yticklabels(a.get_yticklabels(),rotation=30)
plt.show()

# %% [markdown]
# # Interpretation
# * target and cp variable are mildly positively correlated (correlation coeeficient = 0.43)
# * target and thalach variable are also mildly positively correlated (correlation coeeficient = 0.43)
# * target and slope variable are weakly postively correlated(correlation coefficient = 0.35)
# * target and exang variable are variable are mildly negatively correlated (correlation coeeficient = -0.44)
# * target and oldpeak variable are also variable are mildly negatively correlated (correlation coeeficient = -0.44)
# * target and ca variable are weakly negatively correlated (correlation coefficient = -0.38)
# * target and thal variable are weakly negatively correlated (correlation coefficient = -0.38)

# %% [markdown]
# # pairplot

# %%
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target']
sns.pairplot(df[num_var],kind='scatter',diag_kind='hist')
plt.show()

# %% [markdown]
# # comment
# * I have defined a variable num_var. here age,trestbps,chol,'thalach' and 'oldpeak are numerical variables and target is the categorical variable.
# * so, i will check relationships between these varibales.

# %% [markdown]
# ## Analysis of age and other variable

# %%
df['age'].nunique()
# Out:
# 41

# %%
df['age'].describe()
# Out:
# count    1025.000000
# mean       54.434146
# std         9.072290
# min        29.000000
# 25%        48.000000
# 50%        56.000000
# 75%        61.000000
# max        77.000000
# Name: age, dtype: float64

# %% [markdown]
# ## Interpretation
# * the mean value of the age variable is 54.43 years.
# * the minimum and maximum values of age are 29 and 77 years

# %%
f,ax = plt.subplots(figsize=(10,5))
x = df['age']
ax = sns.distplot(x,bins=15)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
sns.stripplot(data = df , x= 'target',y='age')
plt.show()

# %% [markdown]
# # Interpretation
# * we can see that the people suffering from heart disease(target =1) and people are not suffering from heart disease(target=0) have comparable ages.

# %%
f, ax = plt.subplots(figsize=(10,6))
ax = sns.boxplot(data=df, x='target',y='age')
plt.show()

# %% [markdown]
# # Interpretation
# * the mean age of the people who have heart disease is less than the mean age of the people who donot have heart disease.

# %% [markdown]
# # Analyze age and trestbps variable
# * i will plot a scatterplot to visualise the realation between age and trestbps variable

# %%
f, ax = plt.subplots(figsize=(10,6))
ax = sns.scatterplot(data=df , x='age',y='trestbps')
plt.show()

# %% [markdown]
# # Interpretation
# * the above scatterplot shows that there is no correlation between age and trestbps variable

# %%
f, ax = plt.subplots(figsize=(10,6))
ax = sns.regplot(data=df , x='age',y='trestbps')
plt.show()

# %% [markdown]
# # Interpretation
# * The above line shows that linear regression model is not good fit to the data

# %% [markdown]
# # Analyse age and chol variable

# %%
f, ax = plt.subplots(figsize=(10,5))
ax = sns.scatterplot(data=df,x='age',y='chol')
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,5))
ax = sns.regplot(data=df,x='age',y='chol')
plt.show()

# %% [markdown]
# # Interpretation
# * The above line shows that there is a slighly positive correlation betweeen age and chol

# %% [markdown]
# # Analyse chol and thalach variable

# %%
f,ax = plt.subplots(figsize=(10,6))
ax = sns.scatterplot(data=df,x='chol',y='thalach')
plt.show()

# %%
f,ax = plt.subplots(figsize=(10,6))
ax = sns.regplot(data=df,x='chol',y='thalach')
plt.show()

# %% [markdown]
# # Interpretation
# * The above line shows that there is no correlation between chol and thalach variable

# %% [markdown]
# # 10. Dealing with missing values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # Interpretation
# * we see that there is no missing values in the dataset

# %% [markdown]
# # 11. Check with ASSERT statement

# %%
assert pd.notnull(df).all().all()

# %%
assert (df >=0).all().all()

# %% [markdown]
# # Interpretation
# * the above two commands do not throw any error.hence, it is confirmed that ther is no missing or negative values in the dataset.
# * all the values are greater than or equal to zero

# %% [markdown]
# # 12. Outlier Detection
# * i will make boxplots to visualize outliers in the continuous numerical variables:-

# %% [markdown]
# ###### age variable

# %%
df['age'].describe()
# Out:
# count    1025.000000
# mean       54.434146
# std         9.072290
# min        29.000000
# 25%        48.000000
# 50%        56.000000
# 75%        61.000000
# max        77.000000
# Name: age, dtype: float64

# %% [markdown]
# #### Boxplot of age variable

# %%
f,ax = plt.subplots(figsize=(10,6))
sns.boxplot(x=df['age'])
plt.show()

# %% [markdown]
# ###### trestbps variable

# %%
df['trestbps'].describe()
# Out:
# count    1025.000000
# mean      131.611707
# std        17.516718
# min        94.000000
# 25%       120.000000
# 50%       130.000000
# 75%       140.000000
# max       200.000000
# Name: trestbps, dtype: float64

# %% [markdown]
# ##### Boxplot of trestbps variable

# %%
f,ax = plt.subplots(figsize=(10,6))
sns.boxplot(x=df['trestbps'])
plt.show()

# %% [markdown]
# ##### chol variable

# %%
df['chol'].describe()
# Out:
# count    1025.00000
# mean      246.00000
# std        51.59251
# min       126.00000
# 25%       211.00000
# 50%       240.00000
# 75%       275.00000
# max       564.00000
# Name: chol, dtype: float64

# %%
f,ax = plt.subplots(figsize=(10,6))
sns.boxplot(x=df['chol'])
plt.show()

# %% [markdown]
# ###### thalach variable

# %%
df['thalach'].describe()
# Out:
# count    1025.000000
# mean      149.114146
# std        23.005724
# min        71.000000
# 25%       132.000000
# 50%       152.000000
# 75%       166.000000
# max       202.000000
# Name: thalach, dtype: float64

# %% [markdown]
# ###### Boxplot of thalach variable

# %%
f,ax = plt.subplots(figsize=(10,6))
sns.boxplot(x=df['thalach'])
plt.show()

# %% [markdown]
# ### oldpeak variable

# %%
df['oldpeak'].describe()
# Out:
# count    1025.000000
# mean        1.071512
# std         1.175053
# min         0.000000
# 25%         0.000000
# 50%         0.800000
# 75%         1.800000
# max         6.200000
# Name: oldpeak, dtype: float64

# %% [markdown]
# ###### Boxplot of oldpeak variable

# %%
f,ax = plt.subplots(figsize=(10,6))
sns.boxplot(x=df['oldpeak'])
plt.show()

# %% [markdown]
# ### Findings
# * The age variable doesnot contain any outlier.
# * trestbps varible contains outliers to the right side.
# * chol variable contains outliers to the rightside.
# * thalach variable contains outliers to the left side.
# * oldpeak variable contains outliers to the right side.

# %% [markdown]
# ## conclusion

# %% [markdown]
# * In this kernel, we have explored the heart disease dataset. In this kernel, we have implemented many of the strategies presented in the book Think Stats-Exploratory Analysis in python by Allen B Downey. The feature variable is target variable. we have analysed it alone and check its interaction with other variables. we have also discussed how to detect missing data and outliers.

# %% [markdown]
# ## References
#
#  The following references are used to create this kernel
#  * Think Stats - Exploratory Data Analysis in python by Allen B Downey
#  * seaborn API reference
#  * My other kernel
